# %%
from scipy.stats import pearsonr, spearmanr
import Config
import pandas as pd

features_df = pd.read_csv(Config.features_path)



corr, pvalue = spearmanr(features_df['perimeter'], features_df['area'])
print(corr, pvalue)
# Out:
# 0.972499197741793 1.481914467870264e-95

# %%
features_df['perimeter'] = features_df['perimeter'] * 200
features_df.plot();

##i would merge the data with the one that says if theres a melanoma or not an plot the difference

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=932aa97b-f6d2-4889-8f04-d6166675cc2f' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
